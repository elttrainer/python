# %% [markdown]
# <a href="https://colab.research.google.com/github/elttrainer/python/blob/main/Python_error_types_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rectify the code in each cell and **explain the error in comments**

# %% [markdown]
# ### index error

# %%
mylist=[14, "hello", 967]
mylist[2]
#index 6 is beyond the list that contains only 3 elements
# Out:
# 967

# %%
import pandas
import numpy
#libraries not found due to mispelling

# %% [markdown]
# # syntax error

# %%
Print("python errors")
#missing parentheses
# Out:
#   File "<ipython-input-7-4a1ff7dd1a67>", line 1
#     Print"hello world"
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# # key error

# %%
mydictionnary={'True':"hello",'False':"bye", '3':"python"}
mydictionnary['True']
#missing '' for true and false
# Out:
# 'hello'

# %% [markdown]
# # indentation error

# %%
i=14
while i<78:
 print(i)
i+=1
#after while loop we should use an indentation
# Out:
# Streaming output truncated to the last 5000 lines.
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# ...

# %% [markdown]
# # StopIteration

# %%
it=iter([1,2,3])
next(it)
next(it)
next(it)
#iteration beyond the number of elements
# Out:
# StopIterationTraceback (most recent call last)
# <ipython-input-10-dc5f8da513df> in <module>()
#       4 next(it)
#       5 next(it)
# ----> 6 next(it)
#
# StopIteration:

# %% [markdown]
# # TypeError

# %%
15+15
#you can't add a string to an integer only 2 ints for mathematical operations
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-12-49adfd1cdc0d> in <module>()
# ----> 1 '15'+15
#
# TypeError: cannot concatenate 'str' and 'int' objects

# %% [markdown]
# # ValueError

# %%
int('3')
#python is a word and can't be transformed into number(int or float)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-13-2dd638f6810b> in <module>()
# ----> 1 int('python')
#
# ValueError: invalid literal for int() with base 10: 'python'

# %% [markdown]
# # NameError

# %%
print("python")
#object not found
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-14-32886514c262> in <module>()
# ----> 1 python
#
# NameError: name 'python' is not defined

# %% [markdown]
# # ZeroDivisionError

# %%
x=19/1
#you can't divide a number by 0
# Out:
# ZeroDivisionErrorTraceback (most recent call last)
# <ipython-input-15-523d4565e4d9> in <module>()
# ----> 1 x=19/0
#
# ZeroDivisionError: integer division or modulo by zero
